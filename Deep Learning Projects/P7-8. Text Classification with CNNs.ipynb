# %% [markdown]
# **Udemy 7-8. Text Classification with CNNs**

# %% [markdown]
# Torch documentation:
#
# https://torchtext.readthedocs.io/en/latest/data.html

# %%
import torch
import torch.nn as nn
import torchtext.legacy.data as ttd # previous: import torchtext.data as ttd
import torch.nn.functional as F
from torchtext.vocab import GloVe
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
# This Url doesn't work with pd.read_csv
# !wget -nc https://lazyprogrammer.me/course_files/spam.csv

# Note: If a file is downloaded more than once in the same directory -nc can be helpful.
# When -nc is specified, wget refuses to download newer copies of file.
# Out:
# File ‘spam.csv’ already there; not retrieving.

# %%
# !head spam.csv
# Out:
# v1,v2,,,
# ham,"Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...",,,
# ham,Ok lar... Joking wif u oni...,,,
# spam,Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's,,,
# ham,U dun say so early hor... U c already then say...,,,
# ham,"Nah I don't think he goes to usf, he lives around here though",,,
# spam,"FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, �1.50 to rcv",,,
# ham,Even my brother is not like to speak with me. They treat me like aids patent.,,,
# ham,As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune,,,
# spam,WINNER!! As a valued network customer you have been selected to receivea �900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.,,,

# %%
df = pd.read_csv("spam.csv", encoding="ISO-8859-1")
df.head() # strange behaviour in columns 2, 3, 4
# Out:
#      v1  ... Unnamed: 4
# 0   ham  ...        NaN
# 1   ham  ...        NaN
# 2  spam  ...        NaN
# 3   ham  ...        NaN
# 4   ham  ...        NaN
#
# [5 rows x 5 columns]

# %%
# Drop unnexessary columns
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1);
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# Rename columns to something better
df.columns = ['labels', 'data']
df.head()
# Out:
#   labels                                               data
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
# Create binary labels
df['b_labels'] = df['labels'].map({'ham':0, 'spam':1}) # df.map(dict)
df2 = df[['data', 'b_labels']]
df2.head()
# Out:
#                                                 data  b_labels
# 0  Go until jurong point, crazy.. Available only ...         0
# 1                      Ok lar... Joking wif u oni...         0
# 2  Free entry in 2 a wkly comp to win FA Cup fina...         1
# 3  U dun say so early hor... U c already then say...         0
# 4  Nah I don't think he goes to usf, he lives aro...         0

# %%
df2.to_csv('spam2.csv', index=False)

# %%
TEXT = ttd.Field(
    sequential=True, # each value is a sequence of words
    batch_first=True, # Data is of size N x ...
    lower=True, # to lower case the dataset
    tokenize='spacy',
    pad_first=True, # pre-padding instead of post-padding
)

LABEL = ttd.Field(
    sequential=False, # Not a sequential
    use_vocab=False, # we don't do preproceesing on targets to convert vocabs to numbers. They are already digits. If it is True then torch build a vocabulary of word in the dataset.
    is_target=True,
)

# %%
dataset = ttd.TabularDataset(
    path='spam2.csv',
    format='csv', # also could be tsv or json
    skip_header=True, # skip the first row
    fields=[('data', TEXT), ('label', LABEL)] # (name_of_the_field_in_csv_file, object_of_corresponding_field)
)

# Note: Fields must be in order that appears in the file

# %%
train_dataset, test_dataset = dataset.split() # default split_ratio=0.7

# %%
# Internally assign an integer to each token
TEXT.build_vocab(train_dataset)
vocab = TEXT.vocab

# %%
# Note:
# itos and stoi are C-style naming
# vocab.stoi['dog'] = 211
# vocab.itos[211] = 'dog'

print(vocab.itos) # returns a list of vocabs 
print(vocab.stoi) # returns a dictionary of vocab and indices
# Out:
# ['<unk>', '<pad>', '.', 'i', 'to', 'you', ',', '?', 'a', 'the', '!', '...', 'u', 'and', 'in', 'is', 'me', 'my', 'it', 'for', 'do', 'your', '..', 'of', 'that', 'call', 'have', 'on', 'are', "'s", 'now', '2', '&', 'so', 'not', ':', 'ur', 'or', 'with', 'but', 'can', ' ', 'at', 'if', 'we', 'be', 'get', 'just', ';', "'m", 'will', "n't", 'no', 'this', 'nt', 'how', 'up', '-', ')', 'what', 'free', '*', 'from', 'when', '4', 'all', 'ok', 'out', 'go', 'know', '"', '/', 'was', 'good', 'lt;#&gt', 'like', 'got', 'come', 'there', 'he', 'then', 'am', 'its', 'day', "'ll", 'time', 'only', 'want', 'love', 'send', 'text', 'did', 'as', 'about', 'one', 'home', 'txt', 'by', 'see', 'n', 'need', 'back', 'reply', 'going', 'today', 'she', 'still', 'sorry', 'please', 'stop', 'mobile', 'tell', 'any', 'da', 'new', 'ca', 'lor', 'r', 'our', 'phone', 'been', 'week', 'who', 'her', 'they', 'think', 'later', 'take', 'hi', '_', 'claim', 'dear', 'pls', 'd', 'much', 'great', "'", 'has', 'here', 'some', 'well', 'where', 'ì', 'an', 'night', 'too', 'happy', 'him', 'more', 'number', 'oh', 'give', 'hope', 'work', 'had', 'hey', 'message', 'wat', 'make', 'way', 'should', 'yes', 'doing', 'msg', 'prize', 'really', '+', '1', 'say', 'after', 'morning', 'tomorrow', '(', 'cash', 'already', 'k', 'right', 's', 'yeah', "'ve", 'them', 'why', 'would', 'c', 'find', 'thanks', '3', 'let', 'said', 'very', 'anything', 'babe', 'life', 'miss', 'win', 'care', 'ask', 'b', 'something', 'won', 'amp', 'min', 'sure', 'lol', 'pick', 'us', "'re", 'cos', 'even', 'last', 'meet', 'went', 'again', 'could', 'e', 'every', 'his', 'over', 'contact', 'm', 'na', 'sent', 'late', 'next', 'also', 'nokia', 'wait', '150p', 'keep', 'wan', 'customer', 'friends', 'help', 'off', 'per', 'place', 'tone', 'urgent', 'ya', 'before', 'leave', 'service', 'waiting', 'were', 'does', 'first', 'name', 'other', 'things', 'tonight', 'wish', 'told', 'always', 'around', 'down', 'gon', 'many', 'nice', 'soon', 'which', 'wo', 'buy', 'getting', 'guaranteed', 'someone', 'special', ':)', 'sleep', 'yet', 'done', 'live', 'man', 'money', 'thing', 'car', 'chat', 'lunch', 'mins', 'same', 'talk', 'ìï', '16', 'end', 'feel', 'gud', 'smile', 'sms', 'thought', '5', 'awarded', 'year', 'dun', 'few', 'fine', 'haha', 'holiday', 'month', 'people', 'play', 'try', '....', '18', 'eat', 'friend', 'having', 'house', 'may', 'sir', 'thk', '6', 'class', 'cool', 'ill', 'into', 'luv', 'than', 'trying', 'video', 'world', 'because', 'being', 'chance', 'days', 'god', 'half', 'line', 'long', 'stuff', 'use', 'v', 'word', 'x', 'y', '1st', 'coming', 'problem', 'ready', 'receive', 'shit', 'shopping', 'yup', 'best', 'better', 'big', 'bt', 'enjoy', 'guys', 'minutes', 'never', 'remember', '150ppm', 'another', 'apply', 'collect', 'draw', 'finish', 'hello', 'latest', 'meeting', 'mind', 'pay', 'watching', 'wk', '7', 'baby', 'box', 'camera', 'check', 'dat', 'heart', 'kiss', 'lar', 'liao', 'lot', 'missing', 'thanx', 'watch', 'å£1000', '2nd', '9', 'account', 'award', 'job', 'landline', 'might', 'nothing', 'plan', 'princess', 'rate', 'reach', 'real', 'shows', 'speak', 'u.', 'wanna', 'weekend', 'yo', '>', 'entry', 'ever', 'forgot', 'hour', 'jus', 'little', 'must', 'person', 'room', 'selected', 'start', 'two', 'actually', 'ah', 'asked', 'bit', 'boy', 'called', 'came', 'cost', 'dis', 'dunno', 'everything', 'girl', 'guess', 'left', 'leh', 'network', 'okay', 'once', 'probably', 'texts', 'tv', 'wif', '500', 'bad', 'bed', 'between', 'bus', 'dinner', 'enough', 'fun', 'hear', 'offer', 'office', 're', 'says', 'those', 'town', 'weekly', 'xxx', '10p', 'afternoon', 'birthday', 'bored', 'bring', 'calls', 'fuck', 'look', 'maybe', 'po', 'price', 'quite', 'ringtone', 'sexy', 'thank', 'tmr', 'top', 'true', 'anyway', 'code', 'dad', 'den', 'easy', 'feeling', 'gift', 'goes', 'hav', 'join', 'made', 'mail', 'most', 'national', 'orange', 'pa', 'plz', 'put', 'school', 'shall', 'since', 'though', 'tones', 'wake', 'wanted', 'yourself', 'away', 'evening', 'family', 'full', 'i.ll', 'lei', 'looking', 'lose',  ...
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.legacy.vocab.Vocab object at 0x7ff29fd69f10>>, {'<unk>': 0, '<pad>': 1, '.': 2, 'i': 3, 'to': 4, 'you': 5, ',': 6, '?': 7, 'a': 8, 'the': 9, '!': 10, '...': 11, 'u': 12, 'and': 13, 'in': 14, 'is': 15, 'me': 16, 'my': 17, 'it': 18, 'for': 19, 'do': 20, 'your': 21, '..': 22, 'of': 23, 'that': 24, 'call': 25, 'have': 26, 'on': 27, 'are': 28, "'s": 29, 'now': 30, '2': 31, '&': 32, 'so': 33, 'not': 34, ':': 35, 'ur': 36, 'or': 37, 'with': 38, 'but': 39, 'can': 40, ' ': 41, 'at': 42, 'if': 43, 'we': 44, 'be': 45, 'get': 46, 'just': 47, ';': 48, "'m": 49, 'will': 50, "n't": 51, 'no': 52, 'this': 53, 'nt': 54, 'how': 55, 'up': 56, '-': 57, ')': 58, 'what': 59, 'free': 60, '*': 61, 'from': 62, 'when': 63, '4': 64, 'all': 65, 'ok': 66, 'out': 67, 'go': 68, 'know': 69, '"': 70, '/': 71, 'was': 72, 'good': 73, 'lt;#&gt': 74, 'like': 75, 'got': 76, 'come': 77, 'there': 78, 'he': 79, 'then': 80, 'am': 81, 'its': 82, 'day': 83, "'ll": 84, 'time': 85, 'only': 86, 'want': 87, 'love': 88, 'send': 89, 'text': 90, 'did': 91, 'as': 92, 'about': 93, 'one': 94, 'home': 95, 'txt': 96, 'by': 97, 'see': 98, 'n': 99, 'need': 100, 'back': 101, 'reply': 102, 'going': 103, 'today': 104, 'she': 105, 'still': 106, 'sorry': 107, 'please': 108, 'stop': 109, 'mobile': 110, 'tell': 111, 'any': 112, 'da': 113, 'new': 114, 'ca': 115, 'lor': 116, 'r': 117, 'our': 118, 'phone': 119, 'been': 120, 'week': 121, 'who': 122, 'her': 123, 'they': 124, 'think': 125, 'later': 126, 'take': 127, 'hi': 128, '_': 129, 'claim': 130, 'dear': 131, 'pls': 132, 'd': 133, 'much': 134, 'great': 135, "'": 136, 'has': 137, 'here': 138, 'some': 139, 'well': 140, 'where': 141, 'ì': 142, 'an': 143, 'night': 144, 'too': 145, 'happy': 146, 'him': 147, 'more': 148, 'number': 149, 'oh': 150, 'give': 151, 'hope': 152, 'work': 153, 'had': 154, 'hey': 155, 'message': 156, 'wat': 157, 'make': 158, 'way': 159, 'should': 160, 'yes': 161, 'doing': 162, 'msg': 163, 'prize': 164, 'really': 165, '+': 166, '1': 167, 'say': 168, 'after': 169, 'morning': 170, 'tomorrow': 171, '(': 172, 'cash': 173, 'already': 174, 'k': 175, 'right': 176, 's': 177, 'yeah': 178, "'ve": 179, 'them': 180, 'why': 181, 'would': 182, 'c': 183, 'find': 184, 'thanks': 185, '3': 186, 'let': 187, 'said': 188, 'very': 189, 'anything': 190, 'babe': 191, 'life': 192, 'miss': 193, 'win': 194, 'care': 195, 'ask': 196, 'b': 197, 'something': 198, 'won': 199, 'amp': 200, 'min': 201, 'sure': 202, 'lol': 203, 'pick': 204, 'us': 205, "'re": 206, 'cos': 207, 'even': 208, 'last': 209, 'meet': 210, 'went': 211, 'again': 212, 'could': 213, 'e': 214, 'every': 215, 'his': 216, 'over': 217, 'contact': 218, 'm': 219, 'na': 220, 'sent': 221, 'late': 222, 'next': 223, 'also': 224, 'nokia': 225, 'wait': 226, '150p': 227, 'keep': 228, 'wan': 229, 'customer': 230, 'friends': 231, 'help': 232, 'off': 233, 'per': 234, 'place': 235, 'tone': 236, 'urgent': 237, 'ya': 238, 'before': 239, 'leave': 240, 'service': 241, 'waiting': 242, 'were': 243, 'does': 244, 'first': 245, 'name': 246, 'other': 247, 'things': 248, 'tonight': 249, 'wish': 250, 'told': 251, 'always': 252, 'around': 253, 'down': 254, 'gon': 255, 'many': 256, 'nice': 257, 'soon': 258, 'which': 259, 'wo': 260, 'buy': 261, 'getting': 262, 'guaranteed': 263, 'someone': 264, 'special': 265, ':)': 266, 'sleep': 267, 'yet': 268, 'done': 269, 'live': 270, 'man': 271, 'money': 272, 'thing': 273, 'car': 274, 'chat': 275, 'lunch': 276, 'mins': 277, 'same': 278, 'talk': 279, 'ìï': 280, '16': 281, 'end': 282, 'feel': 283, 'gud': 284, 'smile': 285, 'sms': 286, 'thought': 287, '5': 288, 'awarded': 289, 'year': 290, 'dun': 291, 'few': 292, 'fine': 293, 'haha': 294, 'holiday': 295, 'month': 296, 'people': 297, 'play': 298, 'try': 299, '....': 300, '18': 301, 'eat': 302, 'friend': 303, 'having': 304, 'house': 305, 'may': 306, 'sir': 307, 'thk': 308, '6': 309, 'class': 310, 'cool': 311, 'ill': 312, 'into': 313, 'luv': 314, 'than': 315, 'trying': 316, 'vi ...

# %%
train_iter, test_iter = ttd.Iterator.splits(
    (train_dataset, test_dataset),
    sort_key= lambda x: len(x.data), # A function to sort the texts by length - x is an object of Example class
    batch_sizes=(32, 256), # (batch_size_train, batch_size_test)
    device=device, # Automatically transfer the model to device (GPU)
)

# %%
# What is the shape of embedding output
embed = nn.Embedding(num_embeddings=len(vocab), embedding_dim=20).to(device)
for inputs, targets in train_iter:
  print("inputs:", inputs.shape)
  print("targets:", targets.shape)
  out = embed(inputs)
  print("out:", out.shape)
  break
# Out:
# inputs: torch.Size([32, 67])
# targets: torch.Size([32])
# out: torch.Size([32, 67, 20])

# %% [markdown]
# **CNN Arithmetic**
#
# $
# H_{out}=
# ⌊{(H_{in} + 2 × P - D × (K - 1) - 1)/S + 1}⌋
# $
#
# D: Dilation
#
# P: Padding
#
# K: Kernel size
#
# S: Stride
#
# `H_out = np.floor((H_in + 2 * padding - dilation*(kernel_size - 1)-1)/stride +1)`

# %%
# Define the model
class RNN(nn.Module):
  def __init__(self, n_vocab, embed_dim, n_outputs):
    super().__init__()
    self.V = n_vocab
    self.D = embed_dim
    self.K = n_outputs

    # Embedding
    self.embed = nn.Embedding(self.V, self.D) # N x T -> N x T x D


    # Convolution layers
    # Note: in Conv1D we have
    # input (batch size, number of channels, length of signal sequence)  # N x D x T 
    # output (batch size, new number of channels, new length of signal sequence)  # N x D2 x T2
    
    self.conv1 = nn.Conv1d(in_channels=self.D, out_channels=32, kernel_size=3, stride=1, padding=1)
    self.pool1 = nn.MaxPool1d(kernel_size=2)
    self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
    self.pool2 = nn.MaxPool1d(kernel_size=2)
    self.conv3 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)

    # FC layer
    self.fc = nn.Linear(in_features=128, out_features=self.K)
    
  def forward(self, X):
    # embed layer | in: N x T | out: N x T x D
    out = self.embed(X)
    
    # rearrange the data
    out = out.permute(0,2,1) # in: N x T x D | out: N x D x T

    # cnn layer
    out = self.conv1(out) # N x D x T -> N x D x T2  (same)
    out = F.relu(out)
    out = self.pool1(out) # N x D x T2 -> N x D/2 x T2
    out = self.conv2(out) # N x D/2 x T2 -> N x D/2 x T3
    out = F.relu(out)
    out = self.pool2(out) # N x D/2 x T3 -> N x D/4 x T3
    out = self.conv3(out) # N x D/4 x T3 -> N x D/4 x T4
    out = F.relu(out)

    # rearrange the data back
    out = out.permute(0,2,1) # in: N x D x T | out: N x T x D

    # max pool | in: N x T x D | out: N x D
    out, _ = torch.max(out, axis=1)

    # dense layer | in: N x D | out: N x K
    out = self.fc(out)
    return out

# %%
model = RNN(n_vocab=len(vocab), embed_dim=1 ,n_outputs=1)
model.to(device)
# Out:
# RNN(
#   (embed): Embedding(7935, 1)
#   (conv1): Conv1d(1, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#   (pool1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#   (pool2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#   (fc): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
# Loss and Optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
# A function to encapsulate the training loop
def batch_gd(model, criterion, optimizer, train_iter, test_iter, epochs):
  train_losses = np.zeros(epochs)
  test_losses = np.zeros(epochs)
  for it in range(epochs):
    t0 = datetime.now()
    train_loss = []
    for inputs, targets in train_iter:
      targets = targets.view(-1,1).float() # Miner tweak: convert target from (N,) to (N,1) - 2D Array

      # Zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      # Backward and Optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())
    
    # get the train_loss and test_loss
    train_loss = np.mean(train_loss)

    test_loss = []
    for inputs, targets in test_iter:
      targets = targets.view(-1,1).float() # Miner tweak: conver target from (N,) to (N,1) - 2D Array
      outputs = model(inputs)
      loss = criterion(outputs, targets)
      test_loss.append(loss.item())
    test_loss = np.mean(test_loss)

    # Save losses
    train_losses[it] = train_loss
    test_losses[it] = test_loss

    dt = datetime.now() - t0
    if (it + 1) % 1 == 0:
      print(f"Epoch {it+1}/{epochs}, Train_loss: {train_losses[it]:.4f}, Test_loss: {test_losses[it]:.4f}, Duration: {dt}")
  return train_losses, test_losses

# %%
train_losses, test_losses = batch_gd(model, criterion, optimizer, train_iter, test_iter, epochs=15)
# Out:
# Epoch 1/15, Train_loss: 0.0856, Test_loss: 0.1653, Duration: 0:00:01.262587
# Epoch 2/15, Train_loss: 0.0834, Test_loss: 0.2198, Duration: 0:00:01.209194
# Epoch 3/15, Train_loss: 0.0796, Test_loss: 0.1563, Duration: 0:00:01.262889
# Epoch 4/15, Train_loss: 0.0676, Test_loss: 0.1456, Duration: 0:00:01.279367
# Epoch 5/15, Train_loss: 0.0690, Test_loss: 0.1640, Duration: 0:00:02.783345
# Epoch 6/15, Train_loss: 0.0594, Test_loss: 0.1553, Duration: 0:00:02.496579
# Epoch 7/15, Train_loss: 0.0559, Test_loss: 0.1456, Duration: 0:00:01.518283
# Epoch 8/15, Train_loss: 0.0471, Test_loss: 0.1646, Duration: 0:00:01.187933
# Epoch 9/15, Train_loss: 0.0419, Test_loss: 0.1398, Duration: 0:00:01.182082
# Epoch 10/15, Train_loss: 0.0377, Test_loss: 0.1689, Duration: 0:00:01.211057
# Epoch 11/15, Train_loss: 0.0387, Test_loss: 0.1357, Duration: 0:00:01.197752
# Epoch 12/15, Train_loss: 0.0352, Test_loss: 0.1424, Duration: 0:00:01.210466
# Epoch 13/15, Train_loss: 0.0324, Test_loss: 0.1457, Duration: 0:00:01.205467
# Epoch 14/15, Train_loss: 0.0283, Test_loss: 0.1428, Duration: 0:00:01.173876
# Epoch 15/15, Train_loss: 0.0294, Test_loss: 0.1344, Duration: 0:00:01.200015

# %%
plt.plot(train_losses, label="train_losses")
plt.plot(test_losses, label="test_losses")
plt.legend()
plt.show()

# %%
# Accuracy
n_correct = 0
n_total = 0
for inputs, targets in train_iter:
  targets = targets.view(-1,1).float()
  outputs = model(inputs)

  # Get prediction
  predictions = (outputs > 0)

  n_correct += (predictions == targets).sum().item()
  n_total += targets.shape[0]

train_acc = n_correct/n_total


# test accuracy
n_correct = 0
n_total = 0
for inputs, targets in test_iter:
  targets = targets.view(-1,1).float()
  outputs = model(inputs)

  # Get prediction
  predictions = (outputs > 0)

  n_correct += (predictions == targets).sum().item()
  n_total += targets.shape[0]

test_acc = n_correct/n_total

print(f"Train acc: {train_acc:.4f}, Test acc: {test_acc:.4f}")
# Out:
# Train acc: 0.9905, Test acc: 0.9617
